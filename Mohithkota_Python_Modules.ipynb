# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1=np.array([[1,2,3]])

# Create a Numpy array of length 50 with zeroes as its elements
arr2=np.zeros(50)

#Create a Numpy array of length 3x2 with elements of your choice
arr3=np.array([[1,2],[3,4],[5,6]])

arr4= np.matmul(arr1,arr3) #Multiply arr1 and arr3 using Numpy functions

#arr4 = np.dot(arr1,arr3)


#Change 5th element of arr2 to a different number
arr2[4]=99

#Your code here
if np.shape(arr4)==(1,2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# Passed

# %%
import numpy as np

#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.
i=np.array([[1,0,0],[0,1,0],[0,0,1]]) # i= np.identity(3)
x=i*9
y=np.array([[1,1,1],[1,1,1],[1,1,1]])
res=x+y

print(res)
# Out:
# [[10  1  1]
#  [ 1 10  1]
#  [ 1  1 10]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
#Your code here
df = pd.DataFrame(data)
print(df)

#Display the first 2 rows of the data frame
#Your code here
fr = df.head(2)
print(fr)

#Print the age column
#Your code here
print(data1["Age"])

#Filter rows where age is greater than 26
#Your code here
fr = df[df['Age'] > 26]
print(fr)

#Add a new column 'Country' with the value 'India' for all rows
#Your code here

data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']

}
df2= pd.DataFrame(data1)

df2.insert(3,"Country",['India','India','India'], True)

# Fill missing values in the 'Age' column with the mean age
#Your code here
subs= df2['Age'].mean()
print(subs)
df2['Age'].fillna(subs,inplace=True)
print(df2)
# Out:
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# 2  Suresh   35      Delhi
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# [25, None, 35]
#      Name  Age    City
# 1  Mahesh   30  Mumbai
# 2  Suresh   35   Delhi
# 30.0
#      Name   Age       City Country
# 0  Ramesh  25.0  Bangalore   India
# 1  Mahesh  30.0     Mumbai   India
# 2  Suresh  35.0      Delhi   India

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
#Your code here

plt.plot(xpoints,ypoints)
plt.show()


#Plotting with marker: Plot these points with a marker(Star marker)
#Your code here
plt.plot(xpoints,ypoints,marker='*')
plt.title('P1')
plt.show()

#Using fmt format, add circular marker,red color and Dashed line
#Your code here
plt.plot(xpoints,ypoints,marker='o',c='r',linestyle='dashed')
plt.title('P2')
plt.show()

#Add xlabel,ylabel and title for the plot.
#Your code here

plt.plot(xpoints,ypoints,marker='*')

plt.title('P3')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#Create a scatter plot for xpoints and ypoints
#Your code here

plt.scatter(xpoints,ypoints)
plt.title('scattered_plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively

colours = ['blue','green','red','yellow']
#plotting the points
plt.scatter(xpoints,ypoints,c=colours)
plt.title('scatteredplot with diff colours')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
#Your code here

arr1=np.array([1,24,31,45,73,81,94,25])

#Using the random module pick 4 different random numbers from arr1 and return their sum.
#Your code here

sum = np.random.choice(arr1,4,replace=False)
total_sum = np.sum(sum)
print(total_sum)
print(sum)
# Out:
# 230
# [81 24 94 31]
